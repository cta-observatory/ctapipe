# %%
from ctapipe.core import Provenance
from ctapipe.utils import json2fits
from pandas.io.json import json_normalize
from pprint import pprint

# %% [markdown]
# # a few nested activities

# %%
p = Provenance()  # note this is a singleton, so only ever one global provenence object
p.clear()
p.start_activity()
p.add_input_file("test.txt")

p.start_activity("sub")
p.add_input_file("subinput.txt")
p.add_input_file("anothersubinput.txt")
p.add_output_file("suboutput.txt")
p.finish_activity("sub")

p.start_activity("sub2")
p.add_input_file("sub2input.txt")
p.finish_activity("sub2")

p.finish_activity()

# %%
p.finished_activity_names
# Out:
# ['sub', 'sub2', '/Users/kosack/anaconda/bin/python']

# %%
# show the input files for each activity
[ (x['activity_name'], x['input']) for x in p.provenance]
# Out:
# [('sub',
#   ['/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/subinput.txt',
#    '/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/anothersubinput.txt']),
#  ('sub2',
#   ['/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/sub2input.txt']),
#  ('/Users/kosack/anaconda/bin/python',
#   ['/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/test.txt'])]

# %%
# show start/stop/durations:
[ (x['activity_name'],x['duration_min']) for x in p.provenance]
# Out:
# [('sub', 0.00026666666682828577),
#  ('sub2', 0.00025000000006158984),
#  ('/Users/kosack/anaconda/bin/python', 0.0007333333334180736)]

# %%
p.provenance[0]
# Out:
# {'activity_name': 'sub',
#  'duration_min': 0.00026666666682828577,
#  'input': ['/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/subinput.txt',
#   '/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/anothersubinput.txt'],
#  'output': ['/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/suboutput.txt'],
#  'start': {'cpu': {'idle': [89628.240000000005,
#     105927.84,
#     93254.960000000006,
#     105702.64999999999],
#    'ncpu': 4,
#    'nice': [0.0, 0.0, 0.0, 0.0],
#    'system': [11794.719999999999,
#     2697.7600000000002,
#     7829.1599999999999,
#     2716.7600000000002],
#    'user': [11562.209999999999,
#     4356.0,
#     11897.540000000001,
#     4562.1099999999997]},
#   'memory': {'available': 4077432832,
#    'free': 1016569856,
#    'inactive': 3060862976,
#    'total': 17179869184,
#    'wired': 2181410816},
#   'time_utc': '2017-03-07T15:53:29.484'},
#  'stop': {'cpu': {'idle': [89628.240000000005,
#     105927.84,
#     93254.960000000006,
#     105702.66],
#    'ncpu': 4,
#    'nice': [0.0, 0.0, 0.0, 0.0],
#    'system': [11794.73, 2697.77, 7829.1599999999999, 2716.7600000000002],
#    'user': [11562.219999999999,
#     4356.0100000000002,
#     11897.549999999999,
#     4562.1199999999999]},
#   'memory': {'available': 4076892160,
#    'free': 1016029184,
#    'inactive': 3060862976,
#    'total': 17179869184,
#    'wired': 2192994304},
#   'time_utc': '2017-03-07T15:53:29.500'},
#  'system': {'arguments': ['/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py',
#    '-f',
#    '/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json'],
#   'ctapipe_version': '0.3.4.post78+git8df14e6',
#   'executable': '/Users/kosack/anaconda/bin/python',
#   'platform': {'architecture_bits': '64bit',
#    'architecture_linkage': '',
#    'boot_time': '2017-02-28T12:48:00.000',
#    'libcver': ('', ''),
#    'machine': 'x86_64',
#    'node': 'sapmcw8.local',
#    'num_cpus': 4,
#    'processor': 'i386',
#    'release': '16.4.0',
#    'system': 'Darwin',
#    'version': 'Darwin Kernel Version 16.4.0: Thu Dec 22 22:53:21 PST 2016; root:xnu-3789.41.3~3/RELEASE_X86_64'},
#   'python': {'compiler': 'GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)',
#    'implementation': 'CPython',
#    'version': ('3', '6', '0'),
#    'version_string': '3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec 23 2016, 13:19:00) \n[GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]'},
#   'start_time_utc': '2017-03-07T15:53:29.499'}}

# %%
print(p.as_json(indent=2))
# Out:
# [
#   {
#     "activity_name": "sub",
#     "start": {
#       "time_utc": "2017-03-07T15:53:10.520",
#       "memory": {
#         "total": 17179869184,
#         "inactive": 3060858880,
#         "available": 4131934208,
#         "free": 1071075328,
#         "wired": 2507051008
#       },
#       "cpu": {
#         "ncpu": 4,
#         "user": [
#           11560.27,
#           4355.5,
#           11895.64,
#           4561.63
#         ],
#         "nice": [
#           0.0,
#           0.0,
#           0.0,
#           0.0
#         ],
#         "system": [
#           11793.41,
#           2697.35,
#           7828.03,
#           2716.29
#         ],
#         "idle": [
#           89612.52,
#           105909.79,
#           93239.03,
#           105684.64
#         ]
#       }
#     },
#     "stop": {
#       "time_utc": "2017-03-07T15:53:10.531",
#       "memory": {
#         "total": 17179869184,
#         "inactive": 3060858880,
#         "available": 4131180544,
#         "free": 1070321664,
#         "wired": 2508120064
#       },
#       "cpu": {
#         "ncpu": 4,
#         "user": [
#           11560.28,
#           4355.5,
#           11895.64,
#           4561.63
#         ],
#         "nice": [
#           0.0,
#           0.0,
#           0.0,
#           0.0
#         ],
#         "system": [
#           11793.41,
#           2697.35,
#           7828.03,
#           2716.29
#         ],
#         "idle": [
#           89612.52,
#           105909.79,
#           93239.03,
#           105684.65
#         ]
#       }
#     },
#     "system": {
#       "ctapipe_version": "0.3.4.post78+git8df14e6",
#       "executable": "/Users/kosack/anaconda/bin/python",
#       "platform": {
#         "architecture_bits": "64bit",
#         "architecture_linkage": "",
#         "machine": "x86_64",
#         "processor": "i386",
#         "node": "sapmcw8.local",
#         "version": "Darwin Kernel Version 16.4.0: Thu Dec 22 22:53:21 PST 2016; root:xnu-3789.41.3~3/RELEASE_X86_64",
#         "system": "Darwin",
#         "release": "16.4.0",
#         "libcver": [
#           "",
#           ""
#         ],
#         "num_cpus": 4,
#         "boot_time": "2017-02-28T12:48:00.000"
#       },
#       "python": {
#         "version_string": "3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec 23 2016, 13:19:00) \n[GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]",
#         "version": [
#           "3",
#           "6",
#           "0"
#         ],
#         "compiler": "GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)",
#         "implementation": "CPython"
#       },
#       "arguments": [
#         "/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py",
#         "-f",
#         "/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json"
#       ],
#       "start_time_utc": "2017-03-07T15:53:10.530"
#     },
#     "input": [
#       "/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/subinput.txt"
#     ],
#     "output": [
#       "/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/suboutput.txt"
#     ],
#     "duration_min": 0.00018333333331455037
#   },
#   {
#     "activity_name": "sub2",
#     "start": {
#       "time_utc": "2017-03-07T15:53:10.532",
#       "memory": {
#         "total": 17179869184,
#         "inactive": 3060858880,
#         "available": 4131188736,
#         "free": 1070329856,
#         "wired": 2508120064
#       },
#       "cpu": {
#         "ncpu": 4,
#         "user": [
#           11560.28,
#           4355.5,
#           11895.64,
#           4561.63
#         ],
#         "nice": [
#           0.0,
#           0.0,
#           0.0,
#           0.0
#         ],
#         "system": [
#           11793.41,
#           2697.35,
#           7828.03,
#           2716.29
#         ],
#         "idle": [
#           89612.52,
#           105909.79,
#           93239.03,
#           105684.65
#         ]
#       }
#     },
#     "stop": {
#       "time_utc": "2017-03-07T15:53:10.549",
#       "memory": {
#         "total": 17179869184,
#         "inactive": 3060858880,
#         "available": 4132720640,
#         "free": 1071861760,
#         "wired": 2511364096
#       },
#       "cpu": {
#         "ncpu": 4,
#         "user": [
#           11560.29,
#           4355.5,
#           11895.65,
#           4561.63
#         ],
#         "nice": [
#           0.0,
#           0.0,
#           0.0,
#           0.0
#         ],
#         "system": [
#           11793.42,
#           2697.36,
#           7828.04,
#           2716.3
#         ],
#         "idle": [
#           89612.53,
#           105909.8,
#           93239.04,
#           105684.66
#         ]
#       }
#     },
#     "system": {
#       "ctapipe_version": "0.3.4.post78+git8df14e6",
#       "executable": "/Users/kosack/anaconda/bin/python",
#       "platform": {
#         "architecture_bits": "64bit",
#         "architecture_linkage": "",
#         "machine": "x86_64",
#         "processor": "i386",
#         "node": "sapmcw8.local",
#         "version": "Darwin Kernel Version 16.4.0: Thu Dec 22 22:53:21 PST 2016; root:xnu-3789.41.3~3/RELEASE_X86_64",
#         "system": "Darwin",
#         "release": "16.4.0",
#         "libcver": [
#           "",
#           ""
#         ],
#         "num_cpus": 4,
#         "boot_time": "2017-02-28T12:48:00.000"
#       },
#       "python": {
#         "version_string": "3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec 23 2016, 13:19:00) \n[GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]",
#         "version": [
#           "3",
#           "6",
#           "0"
#         ],
#         "compiler": "GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)",
#         "implementation": "CPython"
#       },
#       "arguments": [
#         "/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py",
#         "-f",
#         "/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json"
#       ],
#       "start_time_utc": "2017-03-07T15:53:10.547"
#     },
#     "input": [
#       "/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/sub2input.txt"
#     ],
#     "output": [],
#     "duration_min": 0.0002833333334351096
#   },
#   {
#     "activity_name": "/Users/kosack/anaconda/bin/python",
#     "start": {
#       "time_utc": "2017-03-07T15:53:10.503",
#       "memory": {
#         "total": 17179869184,
#         "inactive": 3060858880,
#         "available": 4132290560,
#         "free": 1071431680,
#         "wired": 2507051008
#       },
#       "cpu": {
#         "ncpu": 4,
#         "user": [
#           11560.26,
#           4355.49,
#           11895.63,
#           4561.62
#         ],
#         "nice": [
#           0.0,
#           0.0,
#           0.0,
#           0.0
#         ],
#         "system": [
#           11793.4,
#           2697.34,
#           7828.02,
#           2716.29
#         ],
#         "idle": [
#           89612.52,
#           105909.78,
#           93239.03,
#           105684.63
#         ]
#       }
#     },
#     "stop": {
#       "time_utc": "2017-03-07T15:53:10.551",
#       "memory": {
#         "total": 17179869184,
#         "inactive": 3060858880,
#         "available": 4132728832,
#         "free": 1071869952,
#         "wired": 2511396864
#       },
#       "cpu": {
#         "ncpu": 4,
#         "user": [
#           11560.29,
#           4355.51,
#           11895.65,
#           4561.63
#         ],
#         "nice": [
#           0.0,
#           0.0,
#           0.0,
#           0.0
#         ],
#         "system": [
#           11793.42,
#           2697.36,
#           7828.04,
#           2716.3
#         ],
#         "idle": [
#           89612.53,
#           105909.8,
#           93239.04,
#           105684.66
#         ]
#       }
#     },
#     "system": {
#       "ctapipe_version": "0.3.4.post78+git8df14e6",
#       "executable": "/Users/kosack/anaconda/bin/python",
#       "platform": {
#         "architecture_bits": "64bit",
#         "architecture_linkage": "",
#         "machine": "x86_64",
#         "processor": "i386",
#         "node": "sapmcw8.local",
#         "version": "Darwin Kernel Version 16.4.0: Thu Dec 22 22:53:21 PST 2016; root:xnu-3789.41.3~3/RELEASE_X86_64",
#         "system": "Darwin",
#         "release": "16.4.0",
#         "libcver": [
#           "",
#           ""
#         ],
#         "num_cpus": 4,
#         "boot_time": "2017-02-28T12:48:00.000"
#       },
#       "python": {
#         "version_string": "3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec 23 2016, 13:19:00) \n[GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]",
#         "version": [
#           "3",
#           "6",
#           "0"
#         ],
#         "compiler": "GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)",
#         "implementation": "CPython"
#       },
#       "arguments": [
#         "/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py",
#         "-f",
#         "/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json"
#       ],
#       "start_time_utc": "2017-03-07T15:53:10.519"
#     },
#     "input": [
#       "/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/test.txt"
#     ],
#     "output": [],
#     "duration_min": 0.0008000000001651131
#   }
# ]

# %% [markdown]
# ## Storing this info in output files
#
# * already this can be stored in something like an HDF5 file header, which allows hierarchies.
# * Try to flatted the data so it can be stored in a key=value header in a **FITS file** (using the FITS extended keyword convention to allow >8 character keywords), or as a table

# %%
def flatten_dict(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '.')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
d = dict(activity=p.provenance)

# %%
pprint(flatten_dict(d))
# Out:
# {'activity.0.activity_name': 'sub',
#  'activity.0.duration_min': 0.00023333333329489392,
#  'activity.0.output.0': '/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/output.txt',
#  'activity.0.start.cpu.idle.0': 89002.070000000007,
#  'activity.0.start.cpu.idle.1': 105224.07000000001,
#  'activity.0.start.cpu.idle.2': 92617.110000000001,
#  'activity.0.start.cpu.idle.3': 104999.10000000001,
#  'activity.0.start.cpu.ncpu': 4,
#  'activity.0.start.cpu.nice.0': 0.0,
#  'activity.0.start.cpu.nice.1': 0.0,
#  'activity.0.start.cpu.nice.2': 0.0,
#  'activity.0.start.cpu.nice.3': 0.0,
#  'activity.0.start.cpu.system.0': 11745.639999999999,
#  'activity.0.start.cpu.system.1': 2681.1799999999998,
#  'activity.0.start.cpu.system.2': 7789.8199999999997,
#  'activity.0.start.cpu.system.3': 2699.71,
#  'activity.0.start.cpu.user.0': 11496.559999999999,
#  'activity.0.start.cpu.user.1': 4335.4799999999996,
#  'activity.0.start.cpu.user.2': 11833.85,
#  'activity.0.start.cpu.user.3': 4541.8299999999999,
#  'activity.0.start.memory.available': 3686473728,
#  'activity.0.start.memory.free': 389894144,
#  'activity.0.start.memory.inactive': 3296579584,
#  'activity.0.start.memory.total': 17179869184,
#  'activity.0.start.memory.wired': 2302689280,
#  'activity.0.start.time_utc': '2017-03-07T15:39:12.971',
#  'activity.0.stop.cpu.idle.0': 89002.080000000002,
#  'activity.0.stop.cpu.idle.1': 105224.08,
#  'activity.0.stop.cpu.idle.2': 92617.110000000001,
#  'activity.0.stop.cpu.idle.3': 104999.11,
#  'activity.0.stop.cpu.ncpu': 4,
#  'activity.0.stop.cpu.nice.0': 0.0,
#  'activity.0.stop.cpu.nice.1': 0.0,
#  'activity.0.stop.cpu.nice.2': 0.0,
#  'activity.0.stop.cpu.nice.3': 0.0,
#  'activity.0.stop.cpu.system.0': 11745.639999999999,
#  'activity.0.stop.cpu.system.1': 2681.1799999999998,
#  'activity.0.stop.cpu.system.2': 7789.8299999999999,
#  'activity.0.stop.cpu.system.3': 2699.7199999999998,
#  'activity.0.stop.cpu.user.0': 11496.57,
#  'activity.0.stop.cpu.user.1': 4335.4799999999996,
#  'activity.0.stop.cpu.user.2': 11833.85,
#  'activity.0.stop.cpu.user.3': 4541.8400000000001,
#  'activity.0.stop.memory.available': 3684728832,
#  'activity.0.stop.memory.free': 388149248,
#  'activity.0.stop.memory.inactive': 3296579584,
#  'activity.0.stop.memory.total': 17179869184,
#  'activity.0.stop.memory.wired': 2302722048,
#  'activity.0.stop.time_utc': '2017-03-07T15:39:12.985',
#  'activity.0.system.arguments.0': '/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py',
#  'activity.0.system.arguments.1': '-f',
#  'activity.0.system.arguments.2': '/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json',
#  'activity.0.system.ctapipe_version': '0.3.4.post78+git8df14e6',
#  'activity.0.system.executable': '/Users/kosack/anaconda/bin/python',
#  'activity.0.system.platform.architecture_bits': '64bit',
#  'activity.0.system.platform.architecture_linkage': '',
#  'activity.0.system.platform.boot_time': '2017-02-28T12:48:00.000',
#  'activity.0.system.platform.libcver': ('', ''),
#  'activity.0.system.platform.machine': 'x86_64',
#  'activity.0.system.platform.node': 'sapmcw8.local',
#  'activity.0.system.platform.num_cpus': 4,
#  'activity.0.system.platform.processor': 'i386',
#  'activity.0.system.platform.release': '16.4.0',
#  'activity.0.system.platform.system': 'Darwin',
#  'activity.0.system.platform.version': 'Darwin Kernel Version 16.4.0: Thu Dec '
#                                        '22 22:53:21 PST 2016; '
#                                        'root:xnu-3789.41.3~3/RELEASE_X86_64',
#  'activity.0.system.python.compiler': 'GCC 4.2.1 Compatible Apple LLVM 6.0 '
#                                       '(clang-600.0.57)',
#  'activity.0.system.python.implementation': 'CPython',
#  'activity.0.system.python.version': ('3', '6', '0'),
#  'activity.0.system.python.version_string': '3.6.0 |Anaconda 4.3.0 (x86_64)| '
#                                             '(default, Dec 23 2016, '
#                                             '13:19:00) \n'
#                                             '[GCC 4.2.1 Compatible Apple LLVM '
#                                             '6.0 (clang-600.0.57)]',
#  'activity.0.system.start_time_utc': '2017-03-07T15:39:12.984',
#  'activity.1.activity_name': 'sub2',
#  'activity.1.duration_min': 0.0002000000000812463,
#  'activity.1.start.cpu.idle.0': 89002.080000000002,
#  'activity.1.start.cpu.idle.1': 105224.08,
#  'activity.1.start.cpu.idle.2': 92617.110000000001,
#  'activity.1.start.cpu.idle.3': 104999.11,
#  'activity.1.start.cpu.ncpu': 4,
#  'activity.1.start.cpu.nice.0': 0.0,
#  'activity.1.start.cpu.nice.1': 0.0,
#  'activity.1.start.cpu.nice.2': 0.0,
#  'activity.1.start.cpu.nice.3': 0.0,
#  'activity.1.start.cpu.system.0': 11745.639999999999,
#  'activity.1.start.cpu.system.1': 2681.1799999999998,
#  'activity.1.start.cpu.system.2': 7789.8299999999999,
#  'activity.1.start.cpu.system.3': 2699.7199999999998,
#  'activity.1.start.cpu.user.0': 11496.57,
#  'activity.1.start.cpu.user.1': 4335.4799999999996,
#  'activity.1.start.cpu.user.2': 11833.85,
#  'activity.1.start.cpu.user.3': 4541.8400000000001,
#  'activity.1.start.memory.available': 3684737024,
#  'activity.1.start.memory.free': 388157440,
#  'activity.1.start.memory.inactive': 3296579584,
#  'activity.1.start.memory.total': 17179869184,
#  'activity.1.start.memory.wired': 2302722048,
#  'activity.1.start.time_utc': '2017-03-07T15:39:12.986',
#  'activity.1.stop.cpu.idle.0': 89002.080000000002,
#  'activity.1.stop.cpu.idle.1': 105224.08,
#  'activity.1.stop.cpu.idle.2': 92617.119999999995,
#  'activity.1.stop.cpu.idle.3': 104999.12,
#  'activity.1.stop.cpu.ncpu': 4,
#  'activity.1.stop.cpu.nice.0': 0.0,
#  'activity.1.stop.cpu.nice.1': 0.0,
#  'activity.1.stop.cpu.nice.2': 0.0,
#  'activity.1.stop.cpu.nice.3': 0.0,
#  'activity.1.stop.cpu.system.0': 11745.65,
#  'activity.1.stop.cpu.system.1': 2681.1799999999998,
#  'activity.1.stop.cpu.system.2': 7789.8299999999999,
#  'activity.1.stop.cpu.system.3': 2699.7199999999998,
#  'activity.1.stop.cpu.user.0': 11496.57,
#  'activity.1.stop.cpu.user.1': 4335.4799999999996,
#  'activity.1.stop.cpu.user.2': 11833.860000000001,
#  'activity.1.stop.cpu.user.3': 4541.8400000000001,
#  'activity.1.stop.memory.available': 3699523584,
#  'activity.1.stop.memory.free': 402944000,
#  'activity.1.stop.memory.inactive': 3296579584,
#  'activity.1.stop.memory.total': 17179869184,
#  'activity.1.stop.memory.wired': 2288173056,
#  'activity.1.stop.time_utc': '2017-03-07T15:39:12.998',
#  'activity.1.system.arguments.0': '/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py',
#  'activity.1.system.arguments.1': '-f',
#  'activity.1.system.arguments.2': '/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json',
#  'activity.1.system.ctapipe_version': '0.3.4.post78+git8df14e6',
#  'activity.1.system.executable': '/Users/kosack/anaconda/bin/python',
#  'activity.1.system.platform.architecture_bits': '64bit',
#  'activity.1.system.platform.architecture_linkage': '',
#  'activity.1.system.platform.boot_time': '2017-02-28T12:48:00.000',
#  'activity.1.system.platform.libcver': ('', ''),
#  'activity.1.system.platform.machine': 'x86_64',
#  'activity.1.system.platform.node': 'sapmcw8.local',
#  'activity.1.system.platform.num_cpus': 4,
#  'activity.1.system.platform.processor': 'i386',
#  'activity.1.system.platform.release': '16.4.0',
#  'activity.1.system.platform.system': 'Darwin',
#  'activity.1.system.platform.version': 'Darwin Kernel Version 16.4.0: Thu Dec '
#                                        '22 22:53:21 PST 2016; '
#                                        'root:xnu-3789.41.3~3/RELEASE_X86_64',
#  'activity.1.system.python.compiler': 'GCC 4.2.1 Compatible Apple LLVM 6.0 '
#                                       '(clang-600.0.57)',
#  'activity.1.system.python.implementation': 'CPython',
#  'activity.1.system.python.version': ('3', '6', '0'),
#  'activity.1.system.python.version_string': '3.6.0 |Anaconda 4.3.0 (x86_64)| '
#                                             '(default, Dec 23 2016, '
#                                             '13:19:00) \n'
#                                             '[GCC 4.2.1 Compatible Apple LLVM '
#                                             '6.0 (clang-600.0.57)]',
#  'activity.1.system.start_time_utc': '2017-03-07T15:39:12.998',
#  'activity.2.activity_name': '/Users/kosack/anaconda/bin/python',
#  'activity.2.duration_min': 0.0007500000000248974,
#  'activity.2.input.0': '/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/test.txt',
#  'activity.2.start.cpu.idle.0': 89002.070000000007,
#  'activity.2.start.cpu.idle.1': 105224.06,
#  'activity.2.start.cpu.idle.2': 92617.110000000001,
#  'activity.2.start.cpu.idle.3': 104999.10000000001,
#  'activity.2.start.cpu.ncpu': 4,
#  'activity.2.start.cpu.nice.0': 0.0,
#  'activity.2.start.cpu.nice.1': 0.0,
#  'activity.2.start.cpu.nice.2': 0.0,
#  'activity.2.start.cpu.nice.3': 0.0,
#  'activity.2.start.cpu.system.0': 11745.629999999999,
#  'activity.2.start.cpu.system.1': 2681.1700000000001,
#  'activity.2.start.cpu.system.2': 7789.8199999999997,
#  'activity.2.start.cpu.system.3': 2699.71,
#  'activity.2.start.cpu.user.0': 11496.559999999999,
#  'activity.2.start.cpu.user.1': 4335.4700000000003,
#  'activity.2.start.cpu.user.2': 11833.84,
#  'activity.2.start.cpu.user.3': 4541.8199999999997,
#  'activity.2.start.memory.available': 3684777984,
#  'activity.2.start.memory.free': 388202496,
#  'activity.2.start.memory.inactive': 3296575488,
#  'activity.2.start.memory.total': 17179869184,
#  'activity.2.start.memory.wired': 2302746624,
#  'activity.2.start.time_utc': '2017-03-07T15:39:12.954',
#  'activity.2.stop.cpu.idle.0': 89002.089999999997,
#  'activity.2.stop.cpu.idle.1': 105224.08,
#  'activity.2.stop.cpu.idle.2': 92617.119999999995,
#  'activity.2.stop.cpu.idle.3': 104999.12,
#  'activity.2.stop.cpu.ncpu': 4,
#  'activity.2.stop.cpu.nice.0': 0.0,
#  'activity.2.stop.cpu.nice.1': 0.0,
#  'activity.2.stop.cpu.nice.2': 0.0,
#  'activity.2.stop.cpu.nice.3': 0.0,
#  'activity.2.stop.cpu.system.0': 11745.65,
#  'activity.2.stop.cpu.system.1': 2681.1799999999998,
#  'activity.2.stop.cpu.system.2': 7789.8299999999999,
#  'activity.2.stop.cpu.system.3': 2699.7199999999998,
#  'activity.2.stop.cpu.user.0': 11496.57,
#  'activity.2.stop.cpu.user.1': 4335.4799999999996,
#  'activity.2.stop.cpu.user.2': 11833.860000000001,
#  'activity.2.stop.cpu.user.3': 4541.8400000000001,
#  'activity.2.stop.memory.available': 3699531776,
#  'activity.2.stop.memory.free': 402952192,
#  'activity.2.stop.memory.inactive': 3296579584,
#  'activity.2.stop.memory.total': 17179869184,
#  'activity.2.stop.memory.wired': 2288173056,
#  'activity.2.stop.time_utc': '2017-03-07T15:39:12.999',
#  'activity.2.system.arguments.0': '/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py',
#  'activity.2.system.arguments.1': '-f',
#  'activity.2.system.arguments.2': '/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json',
#  'activity.2.system.ctapipe_version': '0.3.4.post78+git8df14e6',
#  'activity.2.system.executable': '/Users/kosack/anaconda/bin/python',
#  'activity.2.system.platform.architecture_bits': '64bit',
#  'activity.2.system.platform.architecture_linkage': '',
#  'activity.2.system.platform.boot_time': '2017-02-28T12:48:00.000',
#  'activity.2.system.platform.libcver': ('', ''),
#  'activity.2.system.platform.machine': 'x86_64',
#  'activity.2.system.platform.node': 'sapmcw8.local',
#  'activity.2.system.platform.num_cpus': 4,
#  'activity.2.system.platform.processor': 'i386',
#  'activity.2.system.platform.release': '16.4.0',
#  'activity.2.system.platform.system': 'Darwin',
#  'activity.2.system.platform.version': 'Darwin Kernel Version 16.4.0: Thu Dec '
#                                        '22 22:53:21 PST 2016; '
#                                        'root:xnu-3789.41.3~3/RELEASE_X86_64',
#  'activity.2.system.python.compiler': 'GCC 4.2.1 Compatible Apple LLVM 6.0 '
#                                       '(clang-600.0.57)',
#  'activity.2.system.python.implementation': 'CPython',
#  'activity.2.system.python.version': ('3', '6', '0'),
#  'activity.2.system.python.version_string': '3.6.0 |Anaconda 4.3.0 (x86_64)| '
#                                             '(default, Dec 23 2016, '
#                                             '13:19:00) \n'
#                                             '[GCC 4.2.1 Compatible Apple LLVM '
#                                             '6.0 (clang-600.0.57)]',
#  'activity.2.system.start_time_utc': '2017-03-07T15:39:12.970',
#  'activity.3.activity_name': 'sub',
#  'activity.3.duration_min': 0.0002000000000812463,
#  'activity.3.output.0': '/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/output.txt',
#  'activity.3.start.cpu.idle.0': 89160.800000000003,
#  'activity.3.start.cpu.idle.1': 105399.97,
#  'activity.3.start.cpu.idle.2': 92778.410000000003,
#  'activity.3.start.cpu.idle.3': 105174.75999999999,
#  'activity.3.start.cpu.ncpu': 4,
#  'activity.3.start.cpu.nice.0': 0.0,
#  'activity.3.start.cpu.nice.1': 0.0,
#  'activity.3.start.cpu.nice.2': 0.0,
#  'activity.3.start.cpu.nice.3': 0.0,
#  'activity.3.start.cpu.system.0': 11756.360000000001,
#  'activity.3.start.cpu.system.1': 2684.5500000000002,
#  'activity.3.start.cpu.system.2': 7798.5,
#  'activity.3.start.cpu.system.3': 2703.3400000000001,
#  'activity.3.start.cpu.user.0': 11510.379999999999,
#  'activity.3.start.cpu.user.1': 4339.4899999999998,
#  'activity.3.start.cpu.user.2': 11847.15,
#  'activity.3.start.cpu.user.3': 4545.8299999999999,
#  'activity.3.start.memory.available': 3643539456,
#  'activity.3.start.memory.free': 347230208,
#  'activity.3.start.memory.inactive': 3296309248,
#  'activity.3.start.memory.total': 17179869184,
#  'activity.3.start.memory.wired': 2254262272,
#  'activity.3.start.time_utc': '2017-03-07T15:42:16.254',
#  'activity.3.stop.cpu.idle.0': 89160.800000000003,
#  'activity.3.stop.cpu.idle.1': 105399.97,
#  'activity.3.stop.cpu.idle.2': 92778.410000000003,
#  'activity.3.stop.cpu.idle.3': 105174.77,
#  'activity.3.stop.cpu.ncpu': 4,
#  'activity.3.stop.cpu.nice.0': 0.0,
#  'activity.3.stop.cpu.nice.1': 0.0,
#  'activity.3.stop.cpu.nice.2': 0.0,
#  'activity.3.stop.cpu.nice.3': 0.0,
#  'activity.3.stop.cpu.system.0': 11756.370000000001,
#  'activity.3.stop.cpu.system.1': 2684.5500000000002,
#  'activity.3.stop.cpu.system.2': 7798.5,
#  'activity.3.stop.cpu.system.3': 2703.3400000000001,
#  'activity.3.stop.cpu.user.0': 11510.4,
#  'activity.3.stop.cpu.user.1': 4339.4899999999998,
#  'activity.3.stop.cpu.user.2': 11847.16,
#  'activity.3.stop.cpu.user.3': 4545.8299999999999,
#  'activity.3.stop.memory.available': 3642863616,
#  'activity.3.stop.memory.free': 346554368,
#  'activity.3.stop.memory.inactive': 3296309248,
#  'activity.3.stop.memory.total': 17179869184,
#  'activity.3.stop.memory.wired': 2254467072,
#  'activity.3.stop.time_utc': '2017-03-07T15:42:16.266',
#  'activity.3.system.arguments.0': '/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py',
#  'activity.3.system.arguments.1': '-f',
#  'activity.3.system.arguments.2': '/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json',
#  'activity.3.system.ctapipe_version': '0.3.4.post78+git8df14e6',
#  'activity.3.system.executable': '/Users/kosack/anaconda/bin/python',
#  'activity.3.system.platform.architecture_bits': '64bit',
#  'activity.3.system.platform.architecture_linkage': '',
#  'activity.3.system.platform.boot_time': '2017-02-28T12:48:00.000',
#  'activity.3.system.platform.libcver': ('', ''),
#  'activity.3.system.platform.machine': 'x86_64',
#  'activity.3.system.platform.node': 'sapmcw8.local',
#  'activity.3.system.platform.num_cpus': 4,
#  'activity.3.system.platform.processor': 'i386',
#  'activity.3.system.platform.release': '16.4.0',
#  'activity.3.system.platform.system': 'Darwin',
#  'activity.3.system.platform.version': 'Darwin Kernel Version 16.4.0: Thu Dec '
#                                        '22 22:53:21 PST 2016; '
#                                        'root:xnu-3789.41.3~3/RELEASE_X86_64',
#  'activity.3.system.python.compiler': 'GCC 4.2.1 Compatible Apple LLVM 6.0 '
#                                       '(clang-600.0.57)',
#  'activity.3.system.python.implementation': 'CPython',
#  'activity.3.system.python.version': ('3', '6', '0'),
#  'activity.3.system.python.version_string': '3.6.0 |Anaconda 4.3.0 (x86_64)| '
#                                             '(default, Dec 23 2016, '
#                                             '13:19:00) \n'
#                                             '[GCC 4.2.1 Compatible Apple LLVM '
#                                             '6.0 (clang-600.0.57)]',
#  'activity.3.system.start_time_utc': '2017-03-07T15:42:16.263',
#  'activity.4.activity_name': 'sub2',
#  'activity.4.duration_min': 0.0001833333334744225,
#  'activity.4.start.cpu.idle.0': 89160.800000000003,
#  'activity.4.start.cpu.idle.1': 105399.97,
#  'activity.4.start.cpu.idle.2': 92778.410000000003,
#  'activity.4.start.cpu.idle.3': 105174.77,
#  'activity.4.start.cpu.ncpu': 4,
#  'activity.4.start.cpu.nice.0': 0.0,
#  'activity.4.start.cpu.nice.1': 0.0,
#  'activity.4.start.cpu.nice.2': 0.0,
#  'activity.4.start.cpu.nice.3': 0.0,
#  'activity.4.start.cpu.system.0': 11756.370000000001,
#  'activity.4.start.cpu.system.1': 2684.5500000000002,
#  'activity.4.start.cpu.system.2': 7798.5,
#  'activity.4.start.cpu.system.3': 2703.3400000000001,
#  'activity.4.start.cpu.user.0': 11510.4,
#  'activity.4.start.cpu.user.1': 4339.4899999999998,
#  'activity.4.start.cpu.user.2': 11847.16,
#  'activity.4.start.cpu.user.3': 4545.8299999999999,
#  'activity.4.start.memory.available': 3641831424,
#  'activity.4.start.memory.free': 345522176,
#  'activity.4.start.memory.inactive': 3296309248,
#  'activity.4.start.memory.total': 17179869184,
#  'activity.4.start.memory.wired': 2255798272,
#  'activity.4.start.time_utc': '2017-03-07T15:42:16.268',
#  'activity.4.stop.cpu.idle.0': 89160.809999999998,
#  'activity.4.stop.cpu.idle.1': 105399.98,
#  'activity.4.stop.cpu.idle.2': 92778.410000000003,
#  'activity.4.stop.cpu.idle.3': 105174.78,
#  'activity.4.stop.cpu.ncpu': 4,
#  'activity.4.stop.cpu.nice.0': 0.0,
#  'activity.4.stop.cpu.nice.1': 0.0,
#  'activity.4.stop.cpu.nice.2': 0.0,
#  'activity.4.stop.cpu.nice.3': 0.0,
#  'activity.4.stop.cpu.system.0': 11756.370000000001,
#  'activity.4.stop.cpu.system.1': 2684.5500000000002,
#  'activity.4.stop.cpu.system.2': 7798.5100000000002,
#  'activity.4.stop.cpu.system.3': 2703.3400000000001,
#  'activity.4.stop.cpu.user.0': 11510.4,
#  'activity.4.stop.cpu.user.1': 4339.4899999999998,
#  'activity.4.stop.cpu.user.2': 11847.16,
#  'activity.4.stop.cpu.user.3': 4545.8299999999999,
#  'activity.4.stop.memory.available': 3641053184,
#  'activity.4.stop.memory.free': 344743936,
#  'activity.4.stop.memory.inactive': 3296309248,
#  'activity.4.stop.memory.total': 17179869184,
#  'activity.4.stop.memory.wired': 2255798272,
#  'activity.4.stop.time_utc': '2017-03-07T15:42:16.279',
#  'activity.4.system.arguments.0': '/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py',
#  'activity.4.system.arguments.1': '-f',
#  'activity.4.system.arguments.2': '/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json',
#  'activity.4.system.ctapipe_version': '0.3.4.post78+git8df14e6',
#  'activity.4.system.executable': '/Users/kosack/anaconda/bin/python',
#  'activity.4.system.platform.architecture_bits': '64bit',
#  'activity.4.system.platform.architecture_linkage': '',
#  'activity.4.system.platform.boot_time': '2017-02-28T12:48:00.000',
#  'activity.4.system.platform.libcver': ('', ''),
#  'activity.4.system.platform.machine': 'x86_64',
#  'activity.4.system.platform.node': 'sapmcw8.local',
#  'activity.4.system.platform.num_cpus': 4,
#  'activity.4.system.platform.processor': 'i386',
#  'activity.4.system.platform.release': '16.4.0',
#  'activity.4.system.platform.system': 'Darwin',
#  'activity.4.system.platform.version': 'Darwin Kernel Version 16.4.0: Thu Dec '
#                                        '22 22:53:21 PST 2016; '
#                                        'root:xnu-3789.41.3~3/RELEASE_X86_64',
#  'activity.4.system.python.compiler': 'GCC 4.2.1 Compatible Apple LLVM 6.0 '
#                                       '(clang-600.0.57)',
#  'activity.4.system.python.implementation': 'CPython',
#  'activity.4.system.python.version': ('3', '6', '0'),
#  'activity.4.system.python.version_string': '3.6.0 |Anaconda 4.3.0 (x86_64)| '
#                                             '(default, Dec 23 2016, '
#                                             '13:19:00) \n'
#                                             '[GCC 4.2.1 Compatible Apple LLVM '
#                                             '6.0 (clang-600.0.57)]',
#  'activity.4.system.start_time_utc': '2017-03-07T15:42:16.278',
#  'activity.5.activity_name': '/Users/kosack/anaconda/bin/python',
#  'activity.5.duration_min': 0.0006000000000838668,
#  'activity.5.input.0': '/Users/kosack/Projects/CTA/Working/ctapipe/examples/notebooks/test.txt',
#  'activity.5.start.cpu.idle.0': 89160.800000000003,
#  'activity.5.start.cpu.idle.1': 105399.96000000001,
#  'activity.5.start.cpu.idle.2': 92778.410000000003,
#  'activity.5.start.cpu.idle.3': 105174.75999999999,
#  'activity.5.start.cpu.ncpu': 4,
#  'activity.5.start.cpu.nice.0': 0.0,
#  'activity.5.start.cpu.nice.1': 0.0,
#  'activity.5.start.cpu.nice.2': 0.0,
#  'activity.5.start.cpu.nice.3': 0.0,
#  'activity.5.start.cpu.system.0': 11756.360000000001,
#  'activity.5.start.cpu.system.1': 2684.54,
#  'activity.5.start.cpu.system.2': 7798.4899999999998,
#  'activity.5.start.cpu.system.3': 2703.3299999999999,
#  'activity.5.start.cpu.user.0': 11510.379999999999,
#  'activity.5.start.cpu.user.1': 4339.4799999999996,
#  'activity.5.start.cpu.user.2': 11847.15,
#  'activity.5.start.cpu.user.3': 4545.8199999999997,
#  'activity.5.start.memory.available': 3644125184,
#  'activity.5.start.memory.free': 347815936,
#  'activity.5.start.memory.inactive': 3296309248,
#  'activity.5.start.memory.total': 17179869184,
#  'activity.5.start.memory.wired': 2253213696,
#  'activity.5.start.time_utc': '2017-03-07T15:42:16.244',
#  'activity.5.stop.cpu.idle.0': 89160.809999999998,
#  'activity.5.stop.cpu.idle.1': 105399.98,
#  'activity.5.stop.cpu.idle.2': 92778.410000000003,
#  'activity.5.stop.cpu.idle.3': 105174.78,
#  'activity.5.stop.cpu.ncpu': 4,
#  'activity.5.stop.cpu.nice.0': 0.0,
#  'activity.5.stop.cpu.nice.1': 0.0,
#  'activity.5.stop.cpu.nice.2': 0.0,
#  'activity.5.stop.cpu.nice.3': 0.0,
#  'activity.5.stop.cpu.system.0': 11756.370000000001,
#  'activity.5.stop.cpu.system.1': 2684.5500000000002,
#  'activity.5.stop.cpu.system.2': 7798.5100000000002,
#  'activity.5.stop.cpu.system.3': 2703.3400000000001,
#  'activity.5.stop.cpu.user.0': 11510.4,
#  'activity.5.stop.cpu.user.1': 4339.4899999999998,
#  'activity.5.stop.cpu.user.2': 11847.16,
#  'activity.5.stop.cpu.user.3': 4545.8299999999999,
#  'activity.5.stop.memory.available': 3641061376,
#  'activity.5.stop.memory.free': 344752128,
#  'activity.5.stop.memory.inactive': 3296309248,
#  'activity.5.stop.memory.total': 17179869184,
#  'activity.5.stop.memory.wired': 2255798272,
#  'activity.5.stop.time_utc': '2017-03-07T15:42:16.280',
#  'activity.5.system.arguments.0': '/Users/kosack/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py',
#  'activity.5.system.arguments.1': '-f',
#  'activity.5.system.arguments.2': '/Users/kosack/Library/Jupyter/runtime/kernel-44ee4c95-46a6-40d7-8b7e-c18e4ad5aca8.json',
#  'activity.5.system.ctapipe_version': '0.3.4.post78+git8df14e6',
#  'activity.5.system.executable': '/Users/kosack/anaconda/bin/python',
#  'activity.5.system.platform.architecture_bits': '64bit',
#  'activity.5.system.platform.architecture_linkage': '',
#  'activity.5.system.platform.boot_time': '2017-02-28T12:48:00.000',
#  'activity.5.system.platform.libcver': ('', ''),
#  'activity.5.system.platform.machine': 'x86_64',
#  'activity.5.system.platform.node': 'sapmcw8.local',
#  'activity.5.system.platform.num_cpus': 4,
#  'activity.5.system.platform.processor': 'i386',
#  'activity.5.system.platform.release': '16.4.0',
#  'activity.5.system.platform.system': 'Darwin',
#  'activity.5.system.platform.version': 'Darwin Kernel Version 16.4.0: Thu Dec '
#                                        '22 22:53:21 PST 2016; '
#                                        'root:xnu-3789.41.3~3/RELEASE_X86_64',
#  'activity.5.system.python.compiler': 'GCC 4.2.1 Compatible Apple LLVM 6.0 '
#                                       '(clang-600.0.57)',
#  'activity.5.system.python.implementation': 'CPython',
#  'activity.5.system.python.version': ('3', '6', '0'),
#  'activity.5.system.python.version_string': '3.6.0 |Anaconda 4.3.0 (x86_64)| '
#                                             '(default, Dec 23 2016, '
#                                             '13:19:00) \n'
#                                             '[GCC 4.2.1 Compatible Apple LLVM '
#                                             '6.0 (clang-600.0.57)]',
#  'activity.5.system.start_time_utc': '2017-03-07T15:42:16.253'}

# %%
tab = json_normalize(flatten_dict(d))
tab
# Out:
#   activity.0.activity_name  activity.0.duration_min  \
# 0                      sub                 0.000233
#
#                                  activity.0.output.0  \
# 0  /Users/kosack/Projects/CTA/Working/ctapipe/exa...
#
#    activity.0.start.cpu.idle.0  activity.0.start.cpu.idle.1  \
# 0                     89002.07                    105224.07
#
#    activity.0.start.cpu.idle.2  activity.0.start.cpu.idle.3  \
# 0                     92617.11                     104999.1
#
#    activity.0.start.cpu.ncpu  activity.0.start.cpu.nice.0  \
# 0                          4                          0.0
#
#    activity.0.start.cpu.nice.1                ...                 \
# 0                          0.0                ...
#
#    activity.5.system.platform.num_cpus  activity.5.system.platform.processor  \
# 0                                    4                                  i386
#
#    activity.5.system.platform.release  activity.5.system.platform.system  \
# 0                              16.4.0                             Darwin
#
#                   activity.5.system.platform.version  \
# 0  Darwin Kernel Version 16.4.0: Thu Dec 22 22:53...
#
#                    activity.5.system.python.compiler  \
# 0  GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600...
#
#    activity.5.system.python.implementation  activity.5.system.python.version  \
# 0                                  CPython                         (3, 6, 0)
#
#              activity.5.system.python.version_string  \
# 0  3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec ...
#
#    activity.5.system.start_time_utc
# 0           2017-03-07T15:42:16.253
#
# [1 rows x 418 columns]

# %%
tab2 = json_normalize(d['activity'])
tab2
# Out:
#                        activity_name  duration_min  \
# 0                                sub      0.000233
# 1                               sub2      0.000200
# 2  /Users/kosack/anaconda/bin/python      0.000750
# 3                                sub      0.000200
# 4                               sub2      0.000183
# 5  /Users/kosack/anaconda/bin/python      0.000600
#
#                                                input  \
# 0                                                 []
# 1                                                 []
# 2  [/Users/kosack/Projects/CTA/Working/ctapipe/ex...
# 3                                                 []
# 4                                                 []
# 5  [/Users/kosack/Projects/CTA/Working/ctapipe/ex...
#
#                                               output  \
# 0  [/Users/kosack/Projects/CTA/Working/ctapipe/ex...
# 1                                                 []
# 2                                                 []
# 3  [/Users/kosack/Projects/CTA/Working/ctapipe/ex...
# 4                                                 []
# 5                                                 []
#
#                                start.cpu.idle  start.cpu.ncpu  \
# 0   [89002.07, 105224.07, 92617.11, 104999.1]               4
# 1  [89002.08, 105224.08, 92617.11, 104999.11]               4
# 2   [89002.07, 105224.06, 92617.11, 104999.1]               4
# 3   [89160.8, 105399.97, 92778.41, 105174.76]               4
# 4   [89160.8, 105399.97, 92778.41, 105174.77]               4
# 5   [89160.8, 105399.96, 92778.41, 105174.76]               4
#
#          start.cpu.nice                       start.cpu.system  \
# 0  [0.0, 0.0, 0.0, 0.0]  [11745.64, 2681.18, 7789.82, 2699.71]
# 1  [0.0, 0.0, 0.0, 0.0]  [11745.64, 2681.18, 7789.83, 2699.72]
# 2  [0.0, 0.0, 0.0, 0.0]  [11745.63, 2681.17, 7789.82, 2699.71]
# 3  [0.0, 0.0, 0.0, 0.0]   [11756.36, 2684.55, 7798.5, 2703.34]
# 4  [0.0, 0.0, 0.0, 0.0]   [11756.37, 2684.55, 7798.5, 2703.34]
# 5  [0.0, 0.0, 0.0, 0.0]  [11756.36, 2684.54, 7798.49, 2703.33]
#
#                            start.cpu.user  start.memory.available  \
# 0  [11496.56, 4335.48, 11833.85, 4541.83]              3686473728
# 1  [11496.57, 4335.48, 11833.85, 4541.84]              3684737024
# 2  [11496.56, 4335.47, 11833.84, 4541.82]              3684777984
# 3  [11510.38, 4339.49, 11847.15, 4545.83]              3643539456
# 4   [11510.4, 4339.49, 11847.16, 4545.83]              3641831424
# 5  [11510.38, 4339.48, 11847.15, 4545.82]              3644125184
#
#             ...             system.platform.num_cpus  \
# 0           ...                                    4
# 1           ...                                    4
# 2           ...                                    4
# 3           ...                                    4
# 4           ...                                    4
# 5           ...                                    4
#
#    system.platform.processor  system.platform.release  system.platform.system  \
# 0                       i386                   16.4.0                  Darwin
# 1                       i386                   16.4.0                  Darwin
# 2                       i386                   16.4.0                  Darwin
# 3                       i386                   16.4.0                  Darwin
# 4                       i386                   16.4.0                  Darwin
# 5                       i386                   16.4.0                  Darwin
#
#                              system.platform.version  \
# 0  Darwin Kernel Version 16.4.0: Thu Dec 22 22:53...
# 1  Darwin Kernel Version 16.4.0: Thu Dec 22 22:53...
# 2  Darwin Kernel Version 16.4.0: Thu Dec 22 22:53...
# 3  Darwin Kernel Version 16.4.0: Thu Dec 22 22:53...
# 4  Darwin Kernel Version 16.4.0: Thu Dec 22 22:53...
# 5  Darwin Kernel Version 16.4.0: Thu Dec 22 22:53...
#
#                               system.python.compiler  \
# 0  GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600...
# 1  GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600...
# 2  GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600...
# 3  GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600...
# 4  GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600...
# 5  GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600...
#
#    system.python.implementation system.python.version  \
# 0                       CPython             (3, 6, 0)
# 1                       CPython             (3, 6, 0)
# 2                       CPython             (3, 6, 0)
# 3                       CPython             (3, 6, 0)
# 4                       CPython             (3, 6, 0)
# 5                       CPython             (3, 6, 0)
#
#                         system.python.version_string    system.start_time_utc
# 0  3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec ...  2017-03-07T15:39:12.984
# 1  3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec ...  2017-03-07T15:39:12.998
# 2  3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec ...  2017-03-07T15:39:12.970
# 3  3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec ...  2017-03-07T15:42:16.263
# 4  3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec ...  2017-03-07T15:42:16.278
# 5  3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec ...  2017-03-07T15:42:16.253
#
# [6 rows x 45 columns]

# %%
tab2.loc[2]['stop.cpu.system']
# Out:
# [11745.65, 2681.1799999999998, 7789.8299999999999, 2699.7199999999998]

# %%
tab2.loc[0]
# Out:
# activity_name                                                                         sub
# duration_min                                                                  0.000233333
# input                                                                                  []
# output                                  [/Users/kosack/Projects/CTA/Working/ctapipe/ex...
# start.cpu.idle                                  [89002.07, 105224.07, 92617.11, 104999.1]
# start.cpu.ncpu                                                                          4
# start.cpu.nice                                                       [0.0, 0.0, 0.0, 0.0]
# start.cpu.system                                    [11745.64, 2681.18, 7789.82, 2699.71]
# start.cpu.user                                     [11496.56, 4335.48, 11833.85, 4541.83]
# start.memory.available                                                         3686473728
# start.memory.free                                                               389894144
# start.memory.inactive                                                          3296579584
# start.memory.total                                                            17179869184
# start.memory.wired                                                             2302689280
# start.time_utc                                                    2017-03-07T15:39:12.971
# stop.cpu.idle                                  [89002.08, 105224.08, 92617.11, 104999.11]
# stop.cpu.ncpu                                                                           4
# stop.cpu.nice                                                        [0.0, 0.0, 0.0, 0.0]
# stop.cpu.system                                     [11745.64, 2681.18, 7789.83, 2699.72]
# stop.cpu.user                                      [11496.57, 4335.48, 11833.85, 4541.84]
# stop.memory.available                                                          3684728832
# stop.memory.free                                                                388149248
# stop.memory.inactive                                                           3296579584
# stop.memory.total                                                             17179869184
# stop.memory.wired                                                              2302722048
# stop.time_utc                                                     2017-03-07T15:39:12.985
# system.arguments                        [/Users/kosack/anaconda/lib/python3.6/site-pac...
# system.ctapipe_version                                            0.3.4.post78+git8df14e6
# system.executable                                       /Users/kosack/anaconda/bin/python
# system.platform.architecture_bits                                                   64bit
# system.platform.architecture_linkage
# system.platform.boot_time                                         2017-02-28T12:48:00.000
# system.platform.libcver                                                              (, )
# system.platform.machine                                                            x86_64
# system.platform.node                                                        sapmcw8.local
# system.platform.num_cpus                                                                4
# system.platform.processor                                                            i386
# system.platform.release                                                            16.4.0
# system.platform.system                                                             Darwin
# system.platform.version                 Darwin Kernel Version 16.4.0: Thu Dec 22 22:53...
# system.python.compiler                  GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600...
# system.python.implementation                                                      CPython
# system.python.version                                                           (3, 6, 0)
# system.python.version_string            3.6.0 |Anaconda 4.3.0 (x86_64)| (default, Dec ...
# system.start_time_utc                                             2017-03-07T15:39:12.984
# Name: 0, dtype: object
