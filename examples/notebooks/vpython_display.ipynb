# %% [markdown]
# # A work in progress: exploring a 3D display using VPython
#
# This assumes you have the latest vpython installed via:
#
#    `conda install -c vpython vpython`

# %%
import numpy as np
# %run ../load_one_event.py
# Out:
# {'count': 0,
#  'dl0': {'event_id': 23703,
#          'obs_id': 7514,
#          'tel': {13: {'trigger_time': None,
#                       'trigger_type': 0,
#                       'waveform': array([[[  3.56189928e-01,  -1.84288612e-02,  -5.89871289e-04, ...,
#           -1.78979771e-01,  -2.68174720e-01,   1.42122048e-01],
#         [  6.51643448e-01,   6.16745987e-01,   7.91233289e-01, ...,
#            9.32840811e-02,  -4.63057606e-02,   5.83866207e-02],
#         [ -7.85389479e-02,   2.66038599e-01,   5.24471760e-01, ...,
#           -4.23116495e-01,  -4.57574250e-01,  -3.71429863e-01],
#         ...,
#         [ -1.37614555e-01,  -1.37614555e-01,  -2.61195409e-01, ...,
#           -3.49467446e-01,  -4.55393892e-01,  -4.02430669e-01],
#         [  9.73599416e-01,   7.60257537e-01,   7.95814517e-01, ...,
#           -9.31099797e-02,   8.46749196e-02,  -3.97745099e-02],
#         [  2.06614205e-01,   1.71187253e-01,  -9.45148870e-02, ...,
# ...

# %%
import vpython as v
scene = v.display(width=600, height=600)
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
sub = event.inst.subarray

# %%
tels = []
for itel, coord in enumerate(sub.tel_coords):
    telid = sub.tel_ids[itel]
    color = v.color.white
    if telid in event.trig.tels_with_trigger:
        color = v.color.green
    r = np.sqrt(sub.tel[telid].optics.mirror_area/np.pi).value *3 
    tel= v.cylinder(
        pos=v.vec(coord.x.value, coord.y.value, coord.z.value), 
        axis=v.vec(0,0,1),
        radius=r, color=color
    )
    tels.append(tel)

# %%
impact = v.sphere(pos=v.vec(event.mc.core_x.value, event.mc.core_y.value, 0), 
                  radius=30, color=v.color.red)
